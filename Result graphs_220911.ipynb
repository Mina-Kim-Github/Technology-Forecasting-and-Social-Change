# %%
import pandas as pd

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic', size=20)
plt.text(0.3, 0.3, '한글', size=200)
plt.rc('axes',unicode_minus=False)

# %%
df = pd.read_excel("bargraph.xlsx")
df.head()
# Out:
#         feature   gasoline     diesel   electric   hydrogen
# 0  Class_type_d   9.979912  10.488071  12.960230  13.856918
# 1  Class_type_e  13.951241  14.917693  23.094930  18.769136
# 2  Class_type_g  24.365023  34.651418  22.532921  49.690802
# 3  Class_type_h  12.818171  15.699872  16.702497  26.814283
# 4   Fuel_cost_d  33.397385  20.465509  61.068935  29.361742

# %%
feature = df['feature']

# %%
plt.figure(figsize=(10,20))
plt.barh(feature, df["gasoline"].sort_values())
plt.show()

# %%
plt.figure(figsize=(10,20))
plt.barh(feature, df["diesel"].sort_values())
plt.show()

# %%
plt.figure(figsize=(10,20))
plt.barh(feature, df["electric"].sort_values())
plt.show()

# %%
plt.figure(figsize=(10,20))
plt.barh(feature, df["hydrogen"].sort_values())
plt.show()
